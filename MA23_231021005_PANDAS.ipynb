# %%
import pandas as pd

#using lists
student_data = [
    [100, 90, 10],
    [90, 70, 7],
    [120, 100, 14],
    [80, 50, 2]
]
pd.DataFrame (student_data, columns=['iq', 'marks', 'package',])
# Out:
#     iq  marks  package
# 0  100     90       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
import pandas as pd

#using lists
student_data = [
    [100, 90, 10],
    [90, 70, 7],
    [120, 100, 14],
    [80, 50, 2]
]
pd.DataFrame (student_data)
# Out:
#      0    1   2
# 0  100   90  10
# 1   90   70   7
# 2  120  100  14
# 3   80   50   2

# %%
import pandas as pd

#using lists
student_data = [
    [100, 90, 10],
    [90, 70, 7],
    [120, 100, 14],
    [80, 50, 2]
]
df = pd.DataFrame (student_data, columns=['iq', 'marks', 'package',])
print(df)

df.columns = ['a', 'b', 'c']
df
# Out:
#     iq  marks  package
# 0  100     90       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2
#      a    b   c
# 0  100   90  10
# 1   90   70   7
# 2  120  100  14
# 3   80   50   2

# %%
import pandas as pd
#using dictionary
student_dict = {
    'iq': [100, 90, 80, 120, 0, 0],
    'marks': [80, 70, 100, 90, 0, 0],
    'package': [10, 7, 14, 2, 0, 0]
}

students = pd.DataFrame(student_dict)
students
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2   80    100       14
# 3  120     90        2
# 4    0      0        0
# 5    0      0        0

# %%
students[['iq', 'marks']]
# Out:
#     iq  marks
# 0  100     80
# 1   90     70
# 2   80    100
# 3  120     90
# 4    0      0
# 5    0      0

# %%
data = pd.read_csv("ms_harga_harian.csv")
data
# Out:
#         kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0      PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1      PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2      PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3      PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4      PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
# ...             ...                  ...         ...                   ...
# 45013  PROD-0000037  2008-12-31 00:00:00  CABANG-065                  5280
# 45014  PROD-0000038  2008-12-31 00:00:00  CABANG-065                  6270
# 45015  PROD-0000039  2008-12-31 00:00:00  CABANG-065                  5640
# 45016  PROD-0000040  2008-12-31 00:00:00  CABANG-065                 15380
# 45017  PROD-0000041  2008-12-31 00:00:00  CABANG-065                 14450
#
#        modal_cabang  biaya_cabang
# ...

# %%
print(data.shape) # untuk tau berapa banyak data dan kolomnya
print(data.columns) # untuk nama nama kolom
# Out:
# (45018, 6)
# Index(['kode_produk', 'tgl_berlaku', 'kode_cabang', 'harga_berlaku_cabang',
#        'modal_cabang', 'biaya_cabang'],
#       dtype='object')

# %%
data.head() #untuk melihat 5 data pertama
# Out:
#     kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0  PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1  PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2  PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3  PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4  PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
#
#    modal_cabang  biaya_cabang
# 0         10380           190
# 1          4040            10
# 2          5900            90
# 3          7620            60
# 4          6860            10

# %%
data.head(6) #untuk mencari 6 data pertama
# Out:
#     kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0  PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1  PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2  PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3  PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4  PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
# 5  PROD-0000006  2008-01-01 00:00:00  CABANG-039                  8110
#
#    modal_cabang  biaya_cabang
# 0         10380           190
# 1          4040            10
# 2          5900            90
# 3          7620            60
# 4          6860            10
# 5          7770            10

# %%
data.tail() #untuk melihat 5 data terakhir
# Out:
#         kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 45013  PROD-0000037  2008-12-31 00:00:00  CABANG-065                  5280
# 45014  PROD-0000038  2008-12-31 00:00:00  CABANG-065                  6270
# 45015  PROD-0000039  2008-12-31 00:00:00  CABANG-065                  5640
# 45016  PROD-0000040  2008-12-31 00:00:00  CABANG-065                 15380
# 45017  PROD-0000041  2008-12-31 00:00:00  CABANG-065                 14450
#
#        modal_cabang  biaya_cabang
# 45013          5060            70
# 45014          5960            90
# 45015          5350           130
# 45016         14570            80
# 45017         13600            90

# %%
data[0:6]
# Out:
#     kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0  PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1  PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2  PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3  PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4  PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
# 5  PROD-0000006  2008-01-01 00:00:00  CABANG-039                  8110
#
#    modal_cabang  biaya_cabang
# 0         10380           190
# 1          4040            10
# 2          5900            90
# 3          7620            60
# 4          6860            10
# 5          7770            10

# %%
data[2:7] #untuk melihat data dari nomor 2 sebanyak 7
# Out:
#     kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 2  PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3  PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4  PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
# 5  PROD-0000006  2008-01-01 00:00:00  CABANG-039                  8110
# 6  PROD-0000007  2008-01-01 00:00:00  CABANG-039                  4640
#
#    modal_cabang  biaya_cabang
# 2          5900            90
# 3          7620            60
# 4          6860            10
# 5          7770            10
# 6          4440            20

# %%
data[2:12:3] #untuk
# Out:
#      kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 2   PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 5   PROD-0000006  2008-01-01 00:00:00  CABANG-039                  8110
# 8   PROD-0000009  2008-01-01 00:00:00  CABANG-039                  4690
# 11  PROD-0000012  2008-01-01 00:00:00  CABANG-039                  3440
#
#     modal_cabang  biaya_cabang
# 2           5900            90
# 5           7770            10
# 8           4500            80
# 11          3250            30

# %%
data[(data['modal_cabang']<5000)] #untuk melihat pada kolom modal cabang yang nilainya kurang dari 5000
# Out:
#         kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 1      PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 6      PROD-0000007  2008-01-01 00:00:00  CABANG-039                  4640
# 7      PROD-0000008  2008-01-01 00:00:00  CABANG-039                  1060
# 8      PROD-0000009  2008-01-01 00:00:00  CABANG-039                  4690
# 9      PROD-0000010  2008-01-01 00:00:00  CABANG-039                  1100
# ...             ...                  ...         ...                   ...
# 44988  PROD-0000012  2008-12-31 00:00:00  CABANG-065                  3720
# 44993  PROD-0000017  2008-12-31 00:00:00  CABANG-065                  1310
# 45002  PROD-0000026  2008-12-31 00:00:00  CABANG-065                   910
# 45006  PROD-0000030  2008-12-31 00:00:00  CABANG-065                  4240
# 45008  PROD-0000032  2008-12-31 00:00:00  CABANG-065                  5210
#
#        modal_cabang  biaya_cabang
# ...

# %%
df5000 = data[(data['modal_cabang']<5000)]
df5000['kode_cabang'].unique() #mencari data yang tunggal/ tidak ada samanya (unique)
# Out:
# array(['CABANG-039', 'CABANG-047', 'CABANG-065'], dtype=object)

# %%
df5000['kode_produk'].unique()
# Out:
# array(['PROD-0000002', 'PROD-0000007', 'PROD-0000008', 'PROD-0000009',
#        'PROD-0000010', 'PROD-0000011', 'PROD-0000012', 'PROD-0000017',
#        'PROD-0000020', 'PROD-0000026', 'PROD-0000030', 'PROD-0000032',
#        'PROD-0000037'], dtype=object)

# %%
data['tambahan_modal'] = data['modal_cabang']+5000 #untuk menambahkan kolom tambahan modal dimana kolom tambahan modal berisi jumlah banyak data pada kolom modal cabang lalu dita,bah dengan 5000
data.head()
# Out:
#     kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0  PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1  PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2  PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3  PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4  PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
#
#    modal_cabang  biaya_cabang  tambahan_modal
# 0         10380           190           15380
# 1          4040            10            9040
# 2          5900            90           10900
# 3          7620            60           12620
# 4          6860            10           11860

# %%
data['tambahan_modal'] = data['modal_cabang']+5000
data[(data['kode_produk'] == "PROD-0000001")][['kode_produk','harga_berlaku_cabang']]
# Out:
#         kode_produk  harga_berlaku_cabang
# 0      PROD-0000001                 10980
# 41     PROD-0000001                 11070
# 82     PROD-0000001                 11180
# 123    PROD-0000001                 11130
# 164    PROD-0000001                 10930
# ...             ...                   ...
# 44813  PROD-0000001                 12070
# 44854  PROD-0000001                 12070
# 44895  PROD-0000001                 12310
# 44936  PROD-0000001                 12230
# 44977  PROD-0000001                 12240
#
# [1098 rows x 2 columns]

# %%
sum(data[(data['kode_produk'] == "PROD-0000001")]['harga_berlaku_cabang'])
# Out:
# 12723420

# %%
data[(data['kode_produk'] == "PROD-0000001")].sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of         kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0      PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 41     PROD-0000001  2008-01-02 00:00:00  CABANG-039                 11070
# 82     PROD-0000001  2008-01-03 00:00:00  CABANG-039                 11180
# 123    PROD-0000001  2008-01-04 00:00:00  CABANG-039                 11130
# 164    PROD-0000001  2008-01-05 00:00:00  CABANG-039                 10930
# ...             ...                  ...         ...                   ...
# 44813  PROD-0000001  2008-12-27 00:00:00  CABANG-065                 12070
# 44854  PROD-0000001  2008-12-28 00:00:00  CABANG-065                 12070
# 44895  PROD-0000001  2008-12-29 00:00:00  CABANG-065                 12310
# 44936  PROD-0000001  2008-12-30 00:00:00  CABANG-065                 12230
# 44977  PROD-0000001  2008-12-31 00:00:00  CABANG-065                 12240
#
# ...

# %%
produk = pd.read_csv("ms_produk.csv")
produk
# Out:
#      kode_produk kode_kategori                       nama_produk  unit  \
# 0   PROD-0000001       KTG-003                  bawang merah 1kg     1
# 1   PROD-0000002       KTG-003                 bawang putih 1 kg     1
# 2   PROD-0000003       KTG-003                       buncis 1 kg     1
# 3   PROD-0000004       KTG-003               kacang panjang 1 kg     1
# 4   PROD-0000005       KTG-003                 kacang hijau 1 kg     1
# 5   PROD-0000006       KTG-003                      kentang 1 kg     1
# 6   PROD-0000007       KTG-003                      ketimun 1 kg     1
# 7   PROD-0000008       KTG-003                        kobis 1 kg     1
# 8   PROD-0000009       KTG-003                        tomat 1 kg     1
# 9   PROD-0000010       KTG-003               ubi kayu basah 1 kg     1
# 10  PROD-0000011       KTG-003                    ubi jalar 1 kg     1
# 11  PROD-0000012       KTG-003                       wortel 1 kg     1
# ...

# %% [markdown]
# SOAL-1
# Dalam dataframe data tambahkan kolom nama produk

# %%
data['nama_produk'] = produk['nama_produk'] #TUGAS 1
data[0:42]
# Out:
#      kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0   PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1   PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2   PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3   PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4   PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
# 5   PROD-0000006  2008-01-01 00:00:00  CABANG-039                  8110
# 6   PROD-0000007  2008-01-01 00:00:00  CABANG-039                  4640
# 7   PROD-0000008  2008-01-01 00:00:00  CABANG-039                  1060
# 8   PROD-0000009  2008-01-01 00:00:00  CABANG-039                  4690
# 9   PROD-0000010  2008-01-01 00:00:00  CABANG-039                  1100
# 10  PROD-0000011  2008-01-01 00:00:00  CABANG-039                  1210
# 11  PROD-0000012  2008-01-01 00:00:00  CABANG-039                  3440
# ...

# %%
data.loc[(data['kode_produk'] >= "PROD-000001") & (data['kode_produk'] <= "PROD-0000041"), 'harga_berlaku_cabang'].sum()
# Out:
# 573628500

# %% [markdown]
# SOAL - 2
# buat Dataframe jumlah_produk yang menunjukkan jumlah produk 1 sampai 41 beserta total barang

# %%
results = []
for i in range(1,41):
    kode_produk = f'PROD-00000{i:02d}'
    total_harga = sum(data[(data['kode_produk'] == kode_produk)]['harga_berlaku_cabang'])
    results.append({'kode_produk': kode_produk, 'total_harga' : total_harga})

df = pd.DataFrame(results)
print(df)

data['total'] = df['total_harga']
data.head(42)
# Out:
#      kode_produk  total_harga
# 0   PROD-0000001     12723420
# 1   PROD-0000002      4700600
# 2   PROD-0000003      6966440
# 3   PROD-0000004      9085770
# 4   PROD-0000005      7905370
# 5   PROD-0000006      9152520
# 6   PROD-0000007      5134390
# 7   PROD-0000008      1209790
# 8   PROD-0000009      5349880
# 9   PROD-0000010      1225130
# 10  PROD-0000011      1340010
# 11  PROD-0000012      3946250
# 12  PROD-0000013     14000790
# 13  PROD-0000014     13133790
# 14  PROD-0000015     21401410
# 15  PROD-0000016    110846860
# 16  PROD-0000017      1381190
# 17  PROD-0000018      9869490
# 18  PROD-0000019      6773710
# 19  PROD-0000020      6001690
# 20  PROD-0000021     13409960
# 21  PROD-0000022     81458440
# 22  PROD-0000023     16202460
# 23  PROD-0000024     16638300
# 24  PROD-0000025     11276380
# 25  PROD-0000026      1003320
# 26  PROD-0000027     13566430
# 27  PROD-0000028     61880180
# 28  PROD-0000029      6963260
# 29  PROD-0000030      4537550
# ...

# %%
results = []
for i in range(1, 41):
    kode_produk = f'PROD-00000{i:02d}'
    total_produk = len(data[(data['kode_produk'] == kode_produk )])
    results.append ({'kode_produk': kode_produk, 'total_produk' : total_harga})

df = pd.DataFrame(results)
print(df)

data['jumlah_produl'] = df['total_produk']
data.head(42)
